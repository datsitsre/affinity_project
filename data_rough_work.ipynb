# %%
# !pip install pandas 
# !pip install numpy
# !pip install seaborn
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\DELL\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\DELL\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# ...

# %%
#import library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_trucks = pd.read_csv("trucks.csv",index_col=0)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_20972\2125033513.py:2: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_orders = pd.read_csv("orders.csv", index_col=0)

# %%
df_orders = pd.read_csv("orders.csv", index_col=0)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_20972\3087747070.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_orders = pd.read_csv("orders.csv", index_col=0)

# %%
df_trucks.head()
# Out:
#                                            encodedKey     status  \
# creationDate
# 2022-06-01 08:55:16  8a858f5b8101e7c901811e75b191610d     ACTIVE
# 2022-06-09 16:46:57  8a858f46813e54820181495b67cc468b     ACTIVE
# 2022-08-05 17:30:18  8a858f318267ea7601826f0668096f69     ACTIVE
# 2022-09-06 15:49:50  8a858e458312b8be018312f773d93984  IN_ACTIVE
# 2022-12-06 15:03:23  8a858f4c84e67fe60184e7f2f7d05fc3     ACTIVE
#
#                         truckType  volume(kg)
# creationDate
# 2022-06-01 08:55:16  REEFER_TRUCK       20000
# 2022-06-09 16:46:57  REEFER_TRUCK       15000
# 2022-08-05 17:30:18     BOX_TRUCK       13000
# 2022-09-06 15:49:50     BOX_TRUCK       13000
# 2022-12-06 15:03:23     BOX_TRUCK       13000

# %%
df_orders.head()
# Out:
#                       orderId    clientId         lastModified   status  \
# 0  01GGAPGS3BZKF3AKKRRHPBCMMG   320232240  2025-03-02 18:20:59  PENDING
# 1  01GGAPK4BCXD9S96QXFYD65E20  2420001880  2025-03-02 18:20:59  PENDING
# 2  01GGAPRNS3ET0JC79QTAX8PG46   043730707  2025-03-02 18:20:59  PENDING
# 3  01GGAPX6EG5S77Y5B39SHNXEAM   028737136  2025-03-02 18:20:59  PENDING
# 4  01GGAPYCWBVZQEFFM0DA1J9VT3   038457808  2025-03-02 18:20:59  PENDING
#
#   truckKey  location     fee  volume(kg) deliveryItem        dateGenerated
# 0      NaN  KINTAMPO  6400.0       340.0          BED  2025-03-02 18:20:59
# 1      NaN  KINTAMPO   320.0        17.0          BED  2025-03-02 18:20:59
# 2      NaN  KINTAMPO  3200.0       170.0          BED  2025-03-02 18:20:59
# 3      NaN  KINTAMPO   640.0        34.0          BED  2025-03-02 18:20:59
# 4      NaN  KINTAMPO  1600.0        85.0          BED  2025-03-02 18:20:59

# %%
df_trucks
# Out:
#                                            encodedKey     status  \
# creationDate
# 2022-06-01 08:55:16  8a858f5b8101e7c901811e75b191610d     ACTIVE
# 2022-06-09 16:46:57  8a858f46813e54820181495b67cc468b     ACTIVE
# 2022-08-05 17:30:18  8a858f318267ea7601826f0668096f69     ACTIVE
# 2022-09-06 15:49:50  8a858e458312b8be018312f773d93984  IN_ACTIVE
# 2022-12-06 15:03:23  8a858f4c84e67fe60184e7f2f7d05fc3     ACTIVE
# 2023-04-04 12:12:34  8a858eaa874708ab01874c2ea2da6c5c     ACTIVE
# 2023-04-04 13:02:23  8a858ed8874c30d201874c49b5401105     ACTIVE
# 2023-04-04 13:12:51  8a858ed8874c30d201874c5eae842993     ACTIVE
# 2023-08-09 07:15:06  8a858e9d89d6723f0189d6e44cb312ef  IN_ACTIVE
# 2023-08-09 07:21:02  8a858f6589d435230189d92acfac115d     ACTIVE
# 2023-08-09 07:30:52  8a858f0989d812f80189d9349fc21dab     ACTIVE
# 2023-08-09 09:07:02  8a858e9c89d812f50189d966978731de     ACTIVE
# 2023-08-09 09:08:17  8a858f1989d8b5e10189d95ed4a01ee2     ACTIVE
# ...

# %%
# Recommendation

# %% [markdown]
# <h4>The Recommendation Process</h4>
# <ul>
#     <li> Pick pending orders</li>
#     <li>Check for availability of truck and space</li>
#     <li>Calcuate space for the goods against the allocated space</li>
#     <li>Assign the truck to the pending orders</li>
# </ul>

# %%
df_orders.columns
# Out:
# Index(['orderId', 'clientId', 'lastModified', 'status', 'truckKey', 'location',
#        'fee', 'volume(kg)', 'deliveryItem', 'dateGenerated'],
#       dtype='object')

# %%
# drop some columns
df_orders.drop(
columns=['Unnamed: 0'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[133], line 2
#       1 # drop some columns
# ----> 2 df_orders.drop(
#       3 columns=['Unnamed: 0'], inplace=True)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
# ...

# %%
# Retrieve Pending orders
df_orders_pending = df_orders[df_orders['status'] == 'PENDING']

# %%
df_orders['status'] == 'PENDING'
# Out:
# orderId
# 01GGAPGS3BZKF3AKKRRHPBCMMG     True
# 01GGAPK4BCXD9S96QXFYD65E20     True
# 01GGAPRNS3ET0JC79QTAX8PG46     True
# 01GGAPX6EG5S77Y5B39SHNXEAM     True
# 01GGAPYCWBVZQEFFM0DA1J9VT3     True
#                               ...
# ZTPL-896254-592492            False
# ZVVE-486278-923056            False
# ZWAT-908608-761222            False
# ZWPK-561840-866061            False
# ZZZM-797297-306137            False
# Name: status, Length: 526945, dtype: bool

# %%
df_orders_pending
# Out:
#                            orderId     clientId         lastModified   status  \
# 0       01GGAPGS3BZKF3AKKRRHPBCMMG    320232240  2025-03-02 18:20:59  PENDING
# 1       01GGAPK4BCXD9S96QXFYD65E20   2420001880  2025-03-02 18:20:59  PENDING
# 2       01GGAPRNS3ET0JC79QTAX8PG46    043730707  2025-03-02 18:20:59  PENDING
# 3       01GGAPX6EG5S77Y5B39SHNXEAM    028737136  2025-03-02 18:20:59  PENDING
# 4       01GGAPYCWBVZQEFFM0DA1J9VT3    038457808  2025-03-02 18:20:59  PENDING
# ...                            ...          ...                  ...      ...
# 340007  01J187EZP99VWRDBRA208GKMDY   17354074.0  2025-03-02 18:20:59  PENDING
# 340008  01J187WA3ASVB0BRSEP7M2BM4Q  596083928.0  2025-03-02 18:20:59  PENDING
# 340009  01J188AKG5F6Y5QK85ZE9S9V88  604711603.0  2025-03-02 18:20:59  PENDING
# 340012  01J189EMS0JB0QX69D8R7MKHZ9  512866981.0  2025-03-02 18:20:59  PENDING
# 340013  01J189R5H7CP0C8SZM3F135ZGR  193684670.0  2025-03-02 18:20:59  PENDING
#
# ...

# %%
# code
# loop through orers
# calucate the volume for orders
# if == the truck volume then

# %%
#groupby data by location
df_orders_pending = df_orders[df_orders['status'] == 'PENDING']

# %%
df_orders_pending_location = df_orders_pending.groupby(by=['status', 'location'], sort=True).count()

df_orders_pending_location
# Out:
#                     orderId  clientId  lastModified  truckKey     fee  \
# status  location
# PENDING ACCRA        111379    110683        111379         0  111379
#         BOLGATANGA    32246     32201         32246         0   32246
#         KINTAMPO      13456     13405         13456         0   13456
#         KOFORIDUA     44072     43972         44072         0   44072
#         TEMA         109622    109397        109622         0  109622
#
#                     volume(kg)  deliveryItem  dateGenerated
# status  location
# PENDING ACCRA           111379        111379         111379
#         BOLGATANGA       32246         32246          32246
#         KINTAMPO         13456         13456          13456
#         KOFORIDUA        44072         44072          44072
#         TEMA            109622        109622         109622

# %%
df_orders_pend_locat_accra = df_orders_pending[df_orders_pending['location'] == 'ACCRA'] 
df_orders_pend_locat_kintanpo = df_orders_pending[df_orders_pending['location'] == 'KINTAMPO'] 
df_orders_pend_locat_bolga = df_orders_pending[df_orders_pending['location'] == 'BOLGATANGA'] 
df_orders_pend_locat_tema = df_orders_pending[df_orders_pending['location'] == 'TEMA']

# %%
df_orders_pend_locat_kintanpo
# Out:
#                            orderId     clientId         lastModified   status  \
# 0       01GGAPGS3BZKF3AKKRRHPBCMMG    320232240  2025-03-02 18:20:59  PENDING
# 1       01GGAPK4BCXD9S96QXFYD65E20   2420001880  2025-03-02 18:20:59  PENDING
# 2       01GGAPRNS3ET0JC79QTAX8PG46    043730707  2025-03-02 18:20:59  PENDING
# 3       01GGAPX6EG5S77Y5B39SHNXEAM    028737136  2025-03-02 18:20:59  PENDING
# 4       01GGAPYCWBVZQEFFM0DA1J9VT3    038457808  2025-03-02 18:20:59  PENDING
# ...                            ...          ...                  ...      ...
# 339879  01J183MQYAAJ549HA3VF1XXGY6  813346624.0  2025-03-02 18:20:59  PENDING
# 339918  01J184AXS4J72A5R88ZZ79DMZG  146475014.0  2025-03-02 18:20:59  PENDING
# 339919  01J184CAFM0N15WNFWNFP6NSNZ  579495095.0  2025-03-02 18:20:59  PENDING
# 339947  01J184VN0SMYTR1PS339EK8XG9  364259927.0  2025-03-02 18:20:59  PENDING
# 339958  01J185557Q2QXCVWVRVF6V1E0N  793958352.0  2025-03-02 18:20:59  PENDING
#
# ...

# %%
df_orders_pend_locat_accra
# Out:
#                            orderId     clientId         lastModified   status  \
# 39919   01GS5XK0M8R0J1KS6XE153B963    351848625  2025-03-02 18:20:59  PENDING
# 39922   01GS5XNAGGCS6EM46D9Q6FYHZ1    928683297  2025-03-02 18:20:59  PENDING
# 39926   01GS5XQCHVSHJRHN0ZWRT7CDZA    513563823  2025-03-02 18:20:59  PENDING
# 40401   01GS8AKFGY4M5EG1HCSQNWW1SK    351848625  2025-03-02 18:20:59  PENDING
# 40404   01GS8AMX3WEFBZWZ8GEPH112HZ    081165774  2025-03-02 18:20:59  PENDING
# ...                            ...          ...                  ...      ...
# 340007  01J187EZP99VWRDBRA208GKMDY   17354074.0  2025-03-02 18:20:59  PENDING
# 340008  01J187WA3ASVB0BRSEP7M2BM4Q  596083928.0  2025-03-02 18:20:59  PENDING
# 340009  01J188AKG5F6Y5QK85ZE9S9V88  604711603.0  2025-03-02 18:20:59  PENDING
# 340012  01J189EMS0JB0QX69D8R7MKHZ9  512866981.0  2025-03-02 18:20:59  PENDING
# 340013  01J189R5H7CP0C8SZM3F135ZGR  193684670.0  2025-03-02 18:20:59  PENDING
#
# ...

# %%
df_orders_pending_location
# Out:
#                     clientId  lastModified  truckKey     fee  volume(kg)  \
# status  location
# PENDING ACCRA         110683        111379         0  111379      111379
#         BOLGATANGA     32201         32246         0   32246       32246
#         KINTAMPO       13405         13456         0   13456       13456
#         KOFORIDUA      43972         44072         0   44072       44072
#         TEMA          109397        109622         0  109622      109622
#
#                     deliveryItem  dateGenerated
# status  location
# PENDING ACCRA             111379         111379
#         BOLGATANGA         32246          32246
#         KINTAMPO           13456          13456
#         KOFORIDUA          44072          44072
#         TEMA              109622         109622

# %%
df_orders_pend_locat_bolga.reset_index(drop=True)
# Out:
#                           orderId      clientId         lastModified   status  \
# 0      01GGCN1H2968NXBQDW385Q9FF7     889511377  2025-03-02 18:20:59  PENDING
# 1      01GGCRGRSEVKFFG2A6NSHRE3DJ     037753409  2025-03-02 18:20:59  PENDING
# 2      01GGCS095GP6MVR8DJBZNEDEWV     432607506  2025-03-02 18:20:59  PENDING
# 3      01GGCS8R2WW1J7XC4ZCSCHNWVA     435516794  2025-03-02 18:20:59  PENDING
# 4      01GGCSAYJQAZ9BMG2X05D0PRKX     787659376  2025-03-02 18:20:59  PENDING
# ...                           ...           ...                  ...      ...
# 32241  01J182V2HC07GSXYXX4D7FTT41  2420001309.0  2025-03-02 18:20:59  PENDING
# 32242  01J1830V3WNM0HY1YW84GGG5WE   497318117.0  2025-03-02 18:20:59  PENDING
# 32243  01J1832EWME063M21PSZZNM3JR   737951808.0  2025-03-02 18:20:59  PENDING
# 32244  01J183PZ18VWV4G3A1KVF5F4R2   302009603.0  2025-03-02 18:20:59  PENDING
# 32245  01J183SAD40Q75AXZ1D93EQZQW   528066487.0  2025-03-02 18:20:59  PENDING
#
# ...

# %%
df_orders_pend_locat_bolga.index
# Out:
# Index([    91,    121,    127,    130,    131,    134,    136,    141,    143,
#           145,
#        ...
#        339786, 339789, 339811, 339813, 339828, 339832, 339840, 339843, 339884,
#        339892],
#       dtype='int64', length=32246)

# %%
df_orders_pend_locat_bolga.iloc[:1]
# Out:
#                        orderId   clientId         lastModified   status  \
# 91  01GGCN1H2968NXBQDW385Q9FF7  889511377  2025-03-02 18:20:59  PENDING
#
#    truckKey    location     fee  volume(kg) deliveryItem        dateGenerated
# 91      NaN  BOLGATANGA  3840.0       204.0        TABLE  2025-03-02 18:20:59

# %%
df_orders_pend_locat_bolga.iloc[:1]['fee'].values
# Out:
# array([3840.])

# %%
df_orders_pend_locat_bolga.iloc[:20]['fee'].values[0]
# Out:
# 3840.0

# %%
df_orders_pend_locat_bolga.iloc[:1]['fee'].values[0]
# Out:
# 3840.0

# %%
df_orders_pend_locat_bolga.iloc[:5]['fee'].values[2]
# Out:
# 3200.0

# %%
data_dictionary  = {
    'clientID' : 'clientID',
    'truckkey' : 'truckid',
    'location' : 'location',
    'volumekg' : 'volume(kg)'
}

# %%
len(df_orders_pend_locat_bolga.iloc[:5]['fee'])
# Out:
# 5

# %%
data_len = len(df_orders_pend_locat_bolga.iloc[:]['fee'])
data_truck_len = len(df_trucks.iloc[:]['volume(kg)'])
data_truck_len
# Out:
# 35

# %%
for a in df_trucks.iloc[:]['volume(kg)']:
    print(a)
# Out:
# 20000
# 15000
# 13000
# 13000
# 13000
# 13000
# 13000
# 13000
# 13000
# 13000
# 13000
# 13000
# 12000
# 13000
# 13000
# 13000
# 15000
# 13000
# 13000
# 13000
# 13000
# 13000
# 15000
# 15000
# 13000
# 13000
# 13000
# 13000
# 13000
# 13000
# 15000
# 12000
# 13000
# 20000
# 20000

# %%
data_trucks = [a for a in df_trucks.iloc[:]['volume(kg)']]
print(data_trucks)
# Out:
# [20000, 15000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 12000, 13000, 13000, 13000, 15000, 13000, 13000, 13000, 13000, 13000, 15000, 15000, 13000, 13000, 13000, 13000, 13000, 13000, 15000, 12000, 13000, 20000, 20000]

# %%
df_trucks[['volume(kg)']]['volume(kg)'][0]
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_20972\1528383809.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df_trucks[['volume(kg)']]['volume(kg)'][0]
# 20000

# %%
data_volume_cal = 0
data_truck = len(df_trucks.iloc[:]['volume(kg)'])

for dat_v in range(0, data_len):
    #print(df_orders_pend_locat_bolga.iloc[:]['volume(kg)'].values[dat_v])
    if data_volume_cal < df_trucks.iloc[:]['volume(kg)'].values[0]:
        data_volume_cal += df_orders_pend_locat_bolga.iloc[:]['volume(kg)'].values[data_v] 
    elif

# %%
df_trucks.iloc[:]['volume(kg)'].values[0]
# Out:
# 20000

# %%
for a in df_trucks.iloc[:]['volume(kg)']]
print(data_trucks)

# %%
for data_v in range(0, data_v):
    for v in range(0, data_trucks):

# %%
if the order_sets is less than a truck capacity then
  add additional capacity
 elif the order_set is greater than truck capacity then
    assign an clientID and orderID 
    assign a truck 
    check if truck is status is active

# %%
data_volume_cal = 0
data_v = 0
for data_v in range(0, 5):
    stddore_data = []
    while data_volume_cal <= df_trucks.iloc[:]['volume(kg)'].values[0]:
        data_volume_cal += df_orders_pend_locat_bolga.iloc[:]['volume(kg)'].values[data_v]
    else:
        store_data.append(data_volume_cal)
        #data_volume_cal > df_trucks.iloc[:]['volume(kg)'].values[0]:
        #print('done')
#print(data_volume_cal)
#print(data_v)
print(store_data)
# Out:
# [20196.0, 20196.0, 20196.0, 20196.0, 20196.0, 20196.0, 20196.0, 20196.0, 20196.0, 20196.0]

# %%
map_data = list(map(lambda x, y: x + y, [1, 2], [1, 5]))
print(map_data)
# Out:
# [2, 7]

# %%
print([data_v for data_v in range(0, 5)])
# Out:
# [0, 1, 2, 3, 4]

# %%
df_orders_pending.head()
# Out:
#                       orderId    clientId         lastModified   status  \
# 0  01GGAPGS3BZKF3AKKRRHPBCMMG   320232240  2025-03-02 18:20:59  PENDING
# 1  01GGAPK4BCXD9S96QXFYD65E20  2420001880  2025-03-02 18:20:59  PENDING
# 2  01GGAPRNS3ET0JC79QTAX8PG46   043730707  2025-03-02 18:20:59  PENDING
# 3  01GGAPX6EG5S77Y5B39SHNXEAM   028737136  2025-03-02 18:20:59  PENDING
# 4  01GGAPYCWBVZQEFFM0DA1J9VT3   038457808  2025-03-02 18:20:59  PENDING
#
#   truckKey  location     fee  volume(kg) deliveryItem        dateGenerated
# 0      NaN  KINTAMPO  6400.0       340.0          BED  2025-03-02 18:20:59
# 1      NaN  KINTAMPO   320.0        17.0          BED  2025-03-02 18:20:59
# 2      NaN  KINTAMPO  3200.0       170.0          BED  2025-03-02 18:20:59
# 3      NaN  KINTAMPO   640.0        34.0          BED  2025-03-02 18:20:59
# 4      NaN  KINTAMPO  1600.0        85.0          BED  2025-03-02 18:20:59

# %%
df_orders_pending.groupby(by=['location'])['volume(kg)'].first()
# Out:
# location
# ACCRA          34.0
# BOLGATANGA    204.0
# KINTAMPO      340.0
# KOFORIDUA      34.0
# TEMA           34.0
# Name: volume(kg), dtype: float64

# %%
df_orders_pending.loc[: ('truckKey')] = df_trucks['encodedKey']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[305], line 1
# ----> 1 df_orders_pending.loc[: ('truckKey')] = df_trucks['encodedKey']
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\indexing.py:911, in _LocationIndexer.__setitem__(self, key, value)
#     908 self._has_valid_setitem_indexer(key)
#     910 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 911 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\indexing.py:1942, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1939 # align and set the values
#    1940 if take_split_path:
#    1941     # We have to operate column-wise
# ...

# %%
df_orders_pending
# Out:
#                            orderId     clientId         lastModified   status  \
# 0       01GGAPGS3BZKF3AKKRRHPBCMMG    320232240  2025-03-02 18:20:59  PENDING
# 1       01GGAPK4BCXD9S96QXFYD65E20   2420001880  2025-03-02 18:20:59  PENDING
# 2       01GGAPRNS3ET0JC79QTAX8PG46    043730707  2025-03-02 18:20:59  PENDING
# 3       01GGAPX6EG5S77Y5B39SHNXEAM    028737136  2025-03-02 18:20:59  PENDING
# 4       01GGAPYCWBVZQEFFM0DA1J9VT3    038457808  2025-03-02 18:20:59  PENDING
# ...                            ...          ...                  ...      ...
# 340007  01J187EZP99VWRDBRA208GKMDY   17354074.0  2025-03-02 18:20:59  PENDING
# 340008  01J187WA3ASVB0BRSEP7M2BM4Q  596083928.0  2025-03-02 18:20:59  PENDING
# 340009  01J188AKG5F6Y5QK85ZE9S9V88  604711603.0  2025-03-02 18:20:59  PENDING
# 340012  01J189EMS0JB0QX69D8R7MKHZ9  512866981.0  2025-03-02 18:20:59  PENDING
# 340013  01J189R5H7CP0C8SZM3F135ZGR  193684670.0  2025-03-02 18:20:59  PENDING
#
# ...
